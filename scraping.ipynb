# %%
import requests
from bs4 import BeautifulSoup
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}
def scrape_offers_requests(url):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    offers = []

    # chaque offre = une ligne <tr id="O....">
    for row in soup.select("tr[id^='O']"):

        link = row.select_one("a.lien-details-offre")
        if not link:
            continue

        offer_title = link.get_text(strip=True)
        offer_url = "https://www.emploi-territorial.fr" + link["href"]

        offers.append({
            "title": offer_title,
            "url": offer_url
        })

    return offers

# %%
def scrape_offer_detail(url):
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    # Conteneur principal du détail de l'offre
    main = soup.select_one("div#contenuOffre, div.contenu-offre, main")

    if not main:
        return ""

    # Supprimer éléments inutiles
    for tag in main(["script", "style", "button", "nav"]):
        tag.decompose()

    text = main.get_text(separator="\n", strip=True)
    return text

# %%
URL = "https://www.emploi-territorial.fr/emploi-mobilite/?search-fam-metier=A7&page=20000"

offers = scrape_offers_requests(URL)

corpus = []

for offer in offers:
    print(f"Scraping : {offer['title']}")
    full_text = scrape_offer_detail(offer["url"])

    corpus.append({
        "title": offer["title"],
        "url": offer["url"],
        "text": full_text
    })

    time.sleep(1)  # pour éviter les surchages même si on récupère pas 10K emplois d'un coup
# Out:
# Scraping : Technicien support et déploiement (h/f)
# Scraping : Chef de projet informatique
# Scraping : Ingénieur Bases de données
# Scraping : Adjoint responsable pôle maintenance du service informatique
# Scraping : Technicien informatique  (h/f)
# Scraping : Assistant à Maîtrise d'Ouvrage SI (AMOA) (h/f)
# Scraping : Technicien Système Information Géographique h/f
# Scraping : OPERATEUR EN SIMULATION VIRTUELLE
# Scraping : Développeur O365
# Scraping : Technicien SIG (h/f)
# Scraping : Un ou une responsable d'offre de service Mobilité
# Scraping : Responsable service ressources et direction des systèmes d’information
# Scraping : DES ASSISTANTS EN MAINTENANCE INFORMATIQUE (H/F) - ZONE SUD
# Scraping : ADMINISTRATEUR SYSTEMES ET RESEAUX
# Scraping : Responsable de service informatique F/H
# Scraping : 1 AGENT ADMINISTRATIF, (TIT ou CONT) ORGANISATION DES EVENEMENTS ET COMMUNICATION RESEAUX
# Scraping : Référent.e de proximité SI MDPH - Offre 3849
# Scraping : Chargé de Projet Système Informations Géographiques  (F/H)
# Scraping : CHARGE DE PROJETS
# Scraping : Un-e responsable d'équipe mobile d'assistance numérique - site de Bordeaux
# Scraping : Gestionnaire système d'information patrimoniale (F/H)
# Scraping : Technicien informatique (h/f)
# Scraping : Chef(fe) de projet informatique - social, santé, documentaire
# Scraping : Administrateur infrastructure système / exploitation
# Scraping : Géomaticien (h/f)
# Scraping : Responsable d'applications système d'information social (h/f)
# Scraping : DES ASSISTANTS EN MAINTENANCE INFORMATIQUE (H/F) - ZONE OUEST
# Scraping : Chef(fe) de projets Applications
# Scraping : DES ASSISTANTS EN MAINTENANCE INFORMATIQUE (H/F) - ZONE NORD
# Scraping : DES ASSISTANTS EN MAINTENANCE INFORMATIQUE (H/F) - ZONE EST
# Scraping : Responsable du service des Systèmes d'information (H/F)
# Scraping : Ingénieur automatisme/informatique industrielle (h/f) SAM S04
# Scraping : Technicien/Technicienne support informatique
# Scraping : CHEF DU SECTEUR EVOLUTIONS  803 F/H
# Scraping : Administrateur système et réseaux (h/f)
# Scraping : GESTIONNAIRE DES DEMANDES DE CHANGEMENTS 802 F/H
# Scraping : 1 DIRECTEUR DES SYSTÈMES D'INFORMATION ET DE LA TRANSITION NUMÉRIQUE (H/F)
# Scraping : Directeur des Systèmes d'Information (h/f)
# Scraping : Chef de projet / PMO profil AMOA (h/f)
# Scraping : Automaticien
# Scraping : Chargé-e de Support et Services des Systèmes d'Information / Cybersécurité
# Scraping : RESPONSABLE INFRASTRUCTURE SECURITE OPERATIONNELLE H/F
# Scraping : Responsable informatique (h/f)
# Scraping : Un ou une technicienne
# Scraping : Technicien informatique  (h/f)
# Scraping : Chef de service environnement de travail numérique (F/H)
# Scraping : Technicienne SIG
# Scraping : Chef/ffe de projet Applications Métiers H/F
# Scraping : Directeur des systèmes d'information
# Scraping : CHEF DE PROJET TRANSFORMATION ET INNOVATION  H/F
# Scraping : RÉFÉRENT MÉTIER SOLIS AST
# Scraping : Administrateur système et réseaux (h/f)
# Scraping : Administrateur du réseau et des systèmes  (h/f)
# Scraping : Technicien informatique (h/f)
# Scraping : CHEF DE PROJET INFORMATIQUE H/F
# Scraping : Chargé d’analyse de données et de reporting
# Scraping : Chargé des services supports (h/f)
# Scraping : Administrateur systèmes virtualisation et stockage (h/f)
# Scraping : Responsable d'applications (h/f)
# Scraping : Ingénieur Infrastructure et sécurité H/F
# Scraping : Technicien Systèmes d'Information Géographique (SIG) (h/f)
# Scraping : Gestionnaire d'Applications
# Scraping : Technicien support utilisateurs F/H
# Scraping : Administrateur fonctionnel  (h/f)
# Scraping : Administrateur système et réseau (H/F)
# Scraping : Technicien(ne) informatique - Support N1/N2 & exploitation du SI
# Scraping : Responsable des Systèmes d’Information, chef de projet numérique
# Scraping : Responsable informatique
# Scraping : Chargé(e) du contrôle et de la gestion des données
# Scraping : Architecte infrastructure et services numériques (h/f)
# Scraping : Géomaticien/ne
# Scraping : Technicien informatique (h/f)
# Scraping : Chef de projets métier (h/f)
# Scraping : Chef(fe) de projet assistance tierce maintenance applicative (F/H)
# Scraping : Chargé de projets en transformation numérique (F/H)
# Scraping : Technicien Environnement Numérique des EPLE
# Scraping : SUPERVISEUR DES SYSTEMES D'INFORMATION H/F
# Scraping : CHARGE D'ETUDES  H/F
# Scraping : Technicien informatique (h/f)
# Scraping : UN ADMINISTRATEUR DES SYSTEMES D'INFORMATION (h/f)
# Scraping : Product owner (h/f)
# Scraping : UN(E) TECHNICIEN(NE) SYSTEMES ET RESEAUX (H/F)
# Scraping : Technicien informatique
# Scraping : Sous Directeur Réseau et Moyens Informatiques
# Scraping : Devops
# Scraping : Chef du bureau des systemes d’information (h/f)
# Scraping : L’ATD24 recrute un(e) Chargé(e) d’assistance logiciel métier
# Scraping : Directeur des Services aux Adhérents
# Scraping : Technicien spécialisé de maitenance et de support informatique
# Scraping : développeur / chef de projet
# Scraping : Technicien systèmes et réseaux (f/h)
# Scraping : Technicien support et service (h/f)
# Scraping : Chef de Projet
# Scraping : Responsable d'Unité
# Scraping : Directeur des Solutions Numériques
# Scraping : Chef de projet - Administrateur fonctionnel du Système d'Information Ressources Humaines SIRH
# Scraping : Chargé de mission  (H/F)
# Scraping : Chef de projet (h/f)
# Scraping : INGENIEUR SUIVI APPLICATIONS (H/F)
# Scraping : Directeur/Directrice Solutions - Innovations Numériques
# Scraping : Technicien informatique/télécoms F/H
# Scraping : Technicien en charge du suivi des aménagements physiques du réseau bus
# Scraping : Technicien informatique (h/f)
# Scraping : CHEF(FE) DU SERVICE PRODUCTION
# Scraping : Technicien support Informatique
# Scraping : Technicien Support Applicatifs
# Scraping : CHEF(FE) DE SERVICE INFORMATIQUE – RÉSEAUX – Téléphonie – SGA/SGO – Systel
# Scraping : Chef de projet systèmes d'information  (h/f)
# Scraping : Ingénieur informatique administrateur systèmes et réseaux (h/f)
# Scraping : RESPONSABLE SECURITE DES SYSTEMES D'INFORMATIONS
# Scraping : ADMINISTRATEUR SYSTEME RESEAU ET TELEPHONIE
# Scraping : Responsable exploitation plateforme (h/f)
# Scraping : CHEF DE PROJET INFORMATIQUE (h/f)
# Scraping : Un·e administrateur·rice systèmes et réseaux des services départementaux
# Scraping : Informaticien
# Scraping : Chargé de projets électricité, automatisme et informatique industrielle (H/F)
# Scraping : Ingénieur systèmes et réseaux H/F
# Scraping : UN ANALYSTE D’EXPLOITATION INFORMATIQUE (H/F)
# Scraping : Responsable des Systèmes d’Information
# Scraping : TECHNICIEN INGÉNIERIE DES POSTES DE TRAVAIL H/F
# Scraping : Manager d'équipe - Nord 3 (35827)
# Scraping : Chef de projet informatique (h/f)
# Scraping : Un(e) Responsable du service informatique (H/F)
# Scraping : Assistant support logiciels métiers
# Scraping : Technicien administrateur des services (32268)
# Scraping : Technicien administrateur des services (31979)
# Scraping : Chargé de Mission système d’information RH-Finances
# Scraping : Chargé de projet AF DIAPASON Gestion de la Relation Usagers
# Scraping : TECHNICIEN DEVOPS
# Scraping : Technicien-ne en ingénierie du poste de travail informatique  (H/F)
# Scraping : Chef de projet IA et DATA (F/H)
# Scraping : Chef de projet études et développement des systemes d'information (h/f)
# Scraping : TECHNICIEN INFORMATIQUE POSTE DE TRAVAIL
# Scraping : CHEF DE PROJET PMO
# Scraping : Assistant technique informatique (h/f)
# Scraping : Technicien informatique - F/H
# Scraping : Technicien réseau
# Scraping : Technicien informatique - F/H
# Scraping : Assistant technique informatique (h/f)
# Scraping : Chef de service gestion de projets applicatifs et fonctionnels  (h/f)
# Scraping : TECHNICIEN APPLICATIF METIER-H/F
# Scraping : CHARGÉ DE PROJETS SÉCURITÉ DES SYSTÈMES D'INFORMATION F/H
# Scraping : Référent.e fonctionnel.le Système d'Information gépgraphique - Offre 976
# Scraping : Responsable Fonctionnel Architecte Technique
# Scraping : Chargé de projets RH (h/f)
# Scraping : Chef.fe de projet - sécurisation SI /SCADA
# Scraping : Administrateur de bases de données et système décisionnel
# Scraping : Responsable du pilotage RH et de la modernisation du SIRH
# Scraping : Chef de bureau travaux et maintenance opérationnelle (F/H)
# Scraping : Administrateur fonctionnel (h/f)
# Scraping : ARCHITECTE RESEAUX ET TELECOM F/H - REF 875
# Scraping : Technicien support informatique
# Scraping : Responsable du service informatique (F/H)
# Scraping : CHEF DE PROJET  RESEAUX SUPERVISION VIDEOPROTECTIONS (F/H)
# Scraping : Technicien Réseaux
# Scraping : Chef de projet Etudes F/H
# Scraping : Responsable du pôle Réseaux, Infrastructures, Systèmes et Sécurité (h/f)
# Scraping : CHEF DE PROJET APPLICATIF
# Scraping : Administrateur fonctionnel SIP (h/f)
# Scraping : CHEF DE PROJET FONCTIONNEL
# Scraping : Responsable applicatifs domaine actions sociales et ressources humaines
# Scraping : RESPONSABLE SYSTÈME D'INFORMATION MÉTIER (H/F)
# Scraping : Technicien informatique  (h/f)
# Scraping : Chargé des projets systèmes d'informations métiers (h/f)
# Scraping : Chargé(e) de déploiement M365
# Scraping : Chef de projet numérique
# Scraping : Technicien informatique collèges (h/f)
# Scraping : Pilote de services d’infrastructure réseaux et télécoms (H/F)
# Scraping : Technicien informatique assistance et exploitation bureautique
# Scraping : UN(E) ADMINISTRATEUR(TRICE) SYSTEMES ET RESEAUX
# Scraping : Chargé de mission systèmes métiers (F/H)
# Scraping : Ingénieur systèmes et sécurité (F/H)
# Scraping : un(e) administrateur(trice) des systèmes d’information
# Scraping : Un(e) technicien(ne) système, réseau et téléphonie
# Scraping : Coordinateur de projets SI (h/f)
# Scraping : Technicien.ne informatique
# Scraping : Chargé de projet outils et données d'exploitation
# Scraping : Chargé de projet outils et données d'exploitation
# Scraping : ADMINISTRATEUR DE LA GOUVERNANCE MICROSOFT 365 ET DE LA GESTION DES IDENTITÉS NUMÉRIQUES  F/H
# Scraping : TECHNICIEN INFORMATIQUE
# Scraping : Analyste de données
# Scraping : un chef du service de la maitrise d'ouvrage des collèges  H/F
# Scraping : Technicien de maintenance en informatique
# Scraping : Administrateur systèmes et réseaux  (h/f)
# Scraping : Chef de projet Recette fonctionnelle (Projet de refonte du SI finances)  F/H
# Scraping : Chef de projet comptabilité aval et référentiel comptable (Projet de refonte du SI finances)  F/H
# Scraping : Chef de projet budget et comptabilité d'engagement (Projet de refonte du SI finances)  F/H
# Scraping : CHARGE DE FORMATION ENVIRONNEMENT NUMERIQUE DES AGENTS F/H
# Scraping : Chef de projets web et applications (F/H)
# Scraping : Technicien informatique de proximité
# Scraping : Technicien bureautique polyvalent  (h/f)
# Scraping : ADMINISTRATEUR D'APPLICATION H/F
# Scraping : Responsable de la sécurité des systèmes d'information (h/f)
# Scraping : Technicien réseaux et télécoms
# Scraping : ADMINISTRATEUR EN CYBERSECURITE - REF 100857 - F/H
# Scraping : CHEF OU CHEFFE DE PROJET SYSTÈME D'INFORMATION
# Scraping : Technicien support
# Scraping : Technicien(ne) informatique (F/H)
# Scraping : data manager
# Scraping : RESPONSABLE UNITE EXPLOITATION (F/H) - Direction des systèmes d'information
# Scraping : CORRESPONDANT INFORMATIQUE
# Scraping : ADMINISTRATEUR SIRH - CHARGE DES EVOLUTIONS H/F
# Scraping : Responsable du Service Pilotage et Appui aux Territoires (F/H)
# Scraping : Chef de projet systèmes d’information métier
# Scraping : CHEF·FE D'ÉQUIPE SERVICES NUMÉRIQUES RESSOURCES_504
# Scraping : Technicien informatique
# Scraping : Responsable Systèmes d'Information Délégation F/H
# Scraping : Cartographe
# Scraping : Chargé de projet logiciel métier
# Scraping : Responsable technique - audiovisuel / évènementiels (h/f)
# Scraping : RESPONSABLE SERVICE COMMUN INFORMATIQUE, RÉSEAUX ET TÉLÉPHONIE (F/H)
# Scraping : Chef de Projet ingénierie télécoms, réseau, RIP
# Scraping : 1 informaticien
# Scraping : Chargé de mission pilotage stratégique
# Scraping : Responsable du pôle déploiement assistance et conseil
# Scraping : RESPONSABLE SERVICE DES SYSTEMES D INFORMATIONS
# Scraping : Administrateur Data et CRM
# Scraping : Chef(fe) de projets fonctionnels
# Scraping : CHARGÉ DE PROJETS OPÉRATIONNELS – RELATION À L’USAGER (H/F)
# Scraping : Ingénieur réseau - animateur d'équipe (H/F)
# Scraping : Chargé de mission gouvernance et analyse des données (h/f)
# Scraping : Adjoint.e au responsable du service observation, études et évaluations F/H
# Scraping : Responsable du domaine fonctionnel 1 (chef de projet AMOA) F/H
# Scraping : Technicien informatique Angers (F/H)
# Scraping : Technicien du service DATA et SIG
# Scraping : Chef d'équipe systèmes et réseaux (H/F)
# Scraping : Administrateur système réseau et sécurité (F/H)
# Scraping : Responsable Infrastructure et Production (h/f)
# Scraping : Geomaticien.ne/cartographie
# Scraping : Une ou un Chef de projets systèmes d'information F/H (poste n°A-5209)
# Scraping : Une ou un Responsable d'Unité ingénierie, information géographique et informatique décisionnelle (U3I) F/H (Poste n°A-6378)
# Scraping : Responsable du service modernisation des processus RH / SIRH - F/H
# Scraping : Technicien supports et réseaux
# Scraping : TECHNICIEN (f/h)D'EXPLOITATION DES SYSTÈMES D'INFORMATION - ASSISTANT UTILISATEUR
# Scraping : Un chargé ou une chargée de transformation et conduite du changement
# Scraping : Technicien Support H-F - CDD 6MOIS
# Scraping : Chargé de projet applicatifs métiers et gestion des demandes usagers (h/f)
# Scraping : ADMINISTRATEUR SYSTEME
# Scraping : Chef du service Système et réseaux
# Scraping : CHEF- CHEFFE DE PROJETS - INGÉNIEUR·E INFRASTRUCTURE
# Scraping : Opérateur d'immeuble FTTH
# Scraping : Responsable du pôle matériel et bureautique du service Systèmes d’Information / Réseaux (h/f)
# Scraping : Chef de projet Industrialisation du poste de travail
# Scraping : Technicien de Support et services des systèmes d'information (h/f)
# Scraping : Technicien support et services (h/f)
# Scraping : Chef de service infrastructure technique et exploitation (F/H)
# Scraping : Chargé de projet Plateforme technique des Systèmes d’Information (h/f)
# Scraping : Chef de projet numérique
# Scraping : Un.e gestionnaire de projet migration du logiciel de paie
# Scraping : Chef de Projet Système d'Information Décisionnel (h/f)
# Scraping : TECHNICIEN INFORMATIQUE DE PROXIMITE
# Scraping : Responsable du service Etudes et Développements F/H
# Scraping : Directeur de mission transformation numérique  (h/f)
# Scraping : Administrateur systèmes et réseaux (h/f)
# Scraping : Directeur de mission transformation numérique  (h/f)
# Scraping : TECHNICIEN·NE INFORMATIQUE
# Scraping : Administrateur Systèmes (h/f)
# Scraping : Chef de projets organisation et systèmes d'information
# Scraping : Assistant(e) informatique
# Scraping : Administrateur Systeme SEI (H/F)
# Scraping : Chargé de support applicatif et services des systèmes d'information (h/f)
# Scraping : Une ou un Chef de projet numérique des collèges F/H (Poste n°I-336)
# Scraping : Ingénieur réseaux télécoms
# Scraping : Développeur sénior (h/f)
# Scraping : CHARGE DE LA CARTOGRAPHIE DU SYSTEME D'INFORMATION (F/H) P0041
# Scraping : TECHNICIEN DE PROXIMITÉ H/F
# Scraping : Une  Technicienne ou un Technicien informatique
# Scraping : Administrateur·trice systèmes et réseaux
# Scraping : Géomaticien urbanisme / Instructeur Autorisation Droit des Sols (h/f)
# Scraping : Opérateur technique (F/H)
# Scraping : technicien(ne) réseau et développement
# Scraping : Chef de projet Numérique Digital Workplace
# Scraping : Chef de service infrastructures et sécurité  (h/f)
# Scraping : Technicien télécommunication et réseaux
# Scraping : Ingénieur système et sécurité - SI collèges (h/f)
# Scraping : CHEF DE PROJET METIER FINANCES
# Scraping : Développeur WEB H/F
# Scraping : Agent technique courant faible et connectivité
# Scraping : Technicien.ne Systèmes Réseaux
# Scraping : TECHNICIEN(NE) INFORMATIQUE (H/F)
# Scraping : CHARGE DE SUPPORT ET SERVICES DES SYSTEMES D'INFORMATION
# Scraping : Technicien-ne infrastructures transverses et sécurité informatique  (H/F)
# Scraping : CHEF DE SECTEUR ASSISTANCE CENTRALISEE
# Scraping : Développeur intégrateur de solutions logicielles  (h/f)
# Scraping : Administrateur système H/F
# Scraping : Un(e) technicien support des systèmes d’informations (H/F)
# Scraping : Responsable chef de service support informatique et satisfaction utilisateur
# Scraping : RESPONSABLE CHEF DE SERVICE INFRASTRUCTURE RESEAU (LANWAN), VOIXDATAIMAGES ET SECURITE
# Scraping : TECHNICIEN-NE INFORMATIQUE POSTE DE TRAVAIL (N°13467)
# Scraping : Directeur.trice adjoint.e des Systèmes d'Information - Offre 1521
# Scraping : Gestionnaire bases de données et documentation patrimoniale H/F
# Scraping : Agent Polyvalent Electricien (H/F)
# Scraping : Chef de projet sirh (h/f)
# Scraping : Administrateur systèmes et réseaux informatiques (h/f)
# Scraping : Technicien du système d'information
# Scraping : Technicien informatique
# Scraping : TECHNICIEN INFORMATIQUE
# Scraping : Technicien informatique progiciels  F/H
# Scraping : Technicien postes de travail numérique
# Scraping : Administrateur Système et Gestionnaire Applicatifs Métiers
# Scraping : Un.e chargé.e de support et services des systèmes d’information
# Scraping : R/474 - Responsable de pôle Proximité et Logistique
# Scraping : Développeur ou développeuse Java/VueJS
# Scraping : Responsable Sécurité des Systèmes d'Information - Chef de service informatique
# Scraping : Administrateur système (h/f)
# Scraping : CHEF DE PROJET ARCHITECTE FONCTIONNEL SI (F/H)
# Scraping : Techncien(ne) expert fibre
# Scraping : Ingénieur windows (h/f)
# Scraping : ADMINISTRATEUR.TRICE SYSTEMES ET RESEAUX - F / H
# Scraping : Chef de projet informatique (h/f)
# Scraping : Chef de projet informatique - F/H
# Scraping : Technicien informatique collèges (h/f)
# Scraping : Technicien informatique collèges (h/f)
# Scraping : Technicien informatique de proximité (F/H) - Angers
# Scraping : CHEF DE PROJET DONNÉES (F/H)
# Scraping : BFC 1895 - Technicien applicatif (F/H)
# Scraping : AGENT-E DE MAINTENANCE INFORMATIQUE - 2628
# Scraping : Administrateur applications informatiques (h/f)
# Scraping : Chef de projets SIRH F/H
# Scraping : Informaticien industriel  (h/f)
# Scraping : ADMINISTRATEUR SIG
# Scraping : Administrateur.trice réseau et sécurité
# Scraping : Technicien micro/réseaux et téléphonie (h/f)
# Scraping : Chef de projet SI (h/f)
# Scraping : Technicien gestion opérationnelle et déploiement (h/f)
# Scraping : Technicien informatique de proximité (F/H) - La Roche sur yon
# Scraping : Chargé d'information et de relation à l'usager (H/F)
# Scraping : Chef de projets SI maintenance des solutions applicatives (h/f)
# Scraping : Assistant informatique (h/f)
# Scraping : Assistant informatique (h/f)
# Scraping : CHEF DU SERVICE SYSTEMES D'INFORMATION ET DE COMMUNICATION
# Scraping : Un(e ) Technicien(ne) en Informatique et Réseaux H/F
# Scraping : Chef-fe-s de projet informatique
# Scraping : Chef de projets SI  (h/f)
# Scraping : EXPERT EN CYBERSÉCURITÉ (H/F)
# Scraping : RESPONSABLE DU CENTRE DE SERVICES NUMÉRIQUES – PILOTAGE SUPPORT & PRODUCTION (H/F)
# Scraping : DELEGUE A LA PROTECTION DES DONNEES (H/F)
# Scraping : Technicien(ne) maintenance informatique (H/F)
# Scraping : Technicien systèmes et infrastructures
# Scraping : Technicien(ne) SIC
# Scraping : Ingénieur télécom (F/H)
# Scraping : Chef de projet systèmes MaaS et billettique digitale
# Scraping : Chef de projet informatique Sénior (F/H) –Evreux
# Scraping : Administrateur de bases de données (h/f)
# Scraping : Chef de projet informatique (h/f)
# Scraping : TECHNICIEN SYSTEME ET APPLICATIONS METIERS
# Scraping : Technicien support des systèmes d'informations  (h/f)
# Scraping : Technicien parc informatique
# Scraping : Architecte Technique du Système d'Information
# Scraping : Chargé-e des réseaux des systèmes d'information et des télécommunications
# Scraping : Chef de projet informatique - F/H
# Scraping : TECHNICIEN INFORMATIQUE (F/H)
# Scraping : Un ou une responsable de portefeuille d'applications métiers du SI de Toulouse
# Scraping : Responsable applicatif (h/f)
# Scraping : Chef de projet environnement numérique (F/H)
# Scraping : Administrateur systèmes et réseaux (F/H)
# Scraping : Chargé de pilotage des DSP
# Scraping : Chef de projet - responsable des SI métier (F/H)
# Scraping : Directeur de l'informatique et du numérique
# Scraping : Administrateur-trice système et réseau (f/h)
# Scraping : Chef de projets Transformation Digitale (h/f)
# Scraping : Technicien informatique (h/f)
# Scraping : Chargé Développement & Systèmes d’Information (DEV & SI)
# Scraping : Responsable du secteur assistance utilisateur (h/f)
# Scraping : Technicien systèmes et réseaux (h/f)
# Scraping : Administrateur systèmes et réseaux (h/f)
# Scraping : Responsable des infrastructures (h/f)
# Scraping : Administrateur réseaux et systèmes
# Scraping : Charge de projet intranet et accompagnement aux usages numeriques (h/f)
# Scraping : Technicien/animateur informatique
# Scraping : Administrateur démarches en ligne (h/f)
# Scraping : Technicien support / Administrateur poste de travail (h/f)
# Scraping : Administrateur Système et Bases de données
# Scraping : Technicien d'assistance centralisée (h/f)
# Scraping : Chef du service infrastructures réseaux et télécom (h/f)
# Scraping : Technicien d'Exploitation (h/f)
# Scraping : Responsable de production informatique (H/F)
# Scraping : Technicien d'assistance et de maintenance (h/f)
# Scraping : Technicien systèmes et réseaux (h/f)
# Scraping : Chargé(e) d'assistance logiciels métiers
# Scraping : Consultant transformation innovation (h/f)
# Scraping : Développeur d'applications H/F
# Scraping : Technicien d'assistance en informatique
# Scraping : Administrateur Concerto Arpège / applicatif métier (h/f)
# Scraping : Chef de service et/ou ingénieur systèmes réseaux
# Scraping : CHEF DE PROJET SI
# Scraping : Technicien support informatique et téléphonie (h/f)
# Scraping : Responsable de secteur assistance utilisateur  (h/f)
# Scraping : Responsable du Service Systèmes d'information
# Scraping : Chef de projet SI (h/f)
# Scraping : Chef de projet SI numérique H/F
# Scraping : Un(e) Responsable de la Télégestion
# Scraping : Un technicien progiciel (h/f)
# Scraping : Un Technicien superviseur ou une Technicienne superviseuse téléphonie poste de travail  1021-26
# Scraping : Un Assistant ou une Assistante technique support 841-26
# Scraping : Chef de projet métiers SI Solidarités (h/f)
# Scraping : Responsable de secteur Environnement Numérique des Collèges (h/f)
# Scraping : Assistant expérience numérique usagers (H/F)
# Scraping : Chargé de relation utilisateurs  du système informatique
# Scraping : Technicien informatique (h/f)
# Scraping : Chargé de support et services SI
# Scraping : ANALYSTE DES DONNEES
# Scraping : Administrateur système/ réseaux
# Scraping : Chargé (-e) d'études
# Scraping : Technicien réseaux
# Scraping : Directeur des systèmes d'information et du numérique (h/f)
# Scraping : Chef de projet fonctionnel GMAO (h/f) - CDD 6 mois
# Scraping : Technicien réseaux et télécommunications (F/H)
# Scraping : TECHNICIEN POLYVALENT DMSI
# Scraping : Product Owner EAM – ServiceNow (h/f)
# Scraping : Responsable du Pôle Infrastructure et Exploitation (h/f)
# Scraping : Un chef ou une cheffe de projets du système d'information de Toulouse (mairie, métropole et CCAS)
# Scraping : AGENT D'INTERVENTION TIC
# Scraping : Technicien audio et visioconférence
# Scraping : LOGISTICIEN
# Scraping : Responsable Gestion Active Directory et logiciels métiers
# Scraping : Administrateur (trice) de Base de Données
# Scraping : Coordinateur(trice) technique des systèmes d'informations des EPLE
# Scraping : délégué à la protection des données

# %%
import csv

def save_corpus_to_csv(corpus, filename="corpus_offres_data.csv"):
    with open(filename, mode="w", encoding="utf-8", newline="") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=["title", "url", "text"],
            delimiter=";"
        )
        writer.writeheader()
        for row in corpus:
            writer.writerow(row)
save_corpus_to_csv(corpus)

# petite sauvegarde en csv rapide pour pas le perdre (optionnelle pour la suite)
