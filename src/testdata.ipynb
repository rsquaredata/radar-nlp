# %%
import pandas as pd 

data=pd.read_csv("../data/france_travail.csv")
df=pd.DataFrame(data)

# %%
df.head(20)
# Out:
#                 source offer_id  \
# 0   france-travail-api  201TJVJ
# 1   france-travail-api  201TJTY
# 2   france-travail-api  201SKCC
# 3   france-travail-api  201RYPX
# 4   france-travail-api  201PLPJ
# 5   france-travail-api  201NQYN
# 6   france-travail-api  201NJZC
# 7   france-travail-api  201LQLN
# 8   france-travail-api  201HHQC
# 9   france-travail-api  201CQNX
# 10  france-travail-api  200XSYD
# 11  france-travail-api  200VWFL
# 12  france-travail-api  201PTJX
# 13  france-travail-api  201KFYF
# 14  france-travail-api  201SSQM
# 15  france-travail-api  6979425
# 16  france-travail-api  6963770
# 17  france-travail-api  6962315
# 18  france-travail-api  6932899
# 19  france-travail-api  6906394
#
#                                                   url  \
# 0   https://candidat.francetravail.fr/offres/reche...
# 1   https://candidat.francetravail.fr/offres/reche...
# 2   https://candidat.francetravail.fr/offres/reche...
# ...

# %%
df.describe()
# Out:
#                     source offer_id  \
# count                 1079     1079
# unique                   1     1079
# top     france-travail-api  2641613
# freq                  1079        1
#
#                                                       url  \
# count                                                1079
# unique                                               1079
# top     https://candidat.francetravail.fr/offres/reche...
# freq                                                    1
#
#                        title                  company    location  \
# count                   1079                      744        1079
# unique                   862                      466         466
# top     Data scientist (H/F)  Forums Talents Handicap  75 - Paris
# freq                      17                       30          87
#
#                   published_date contract_type           salary  \
# count                       1079          1079              568
# ...

# %%
df.tail()
# Out:
#                   source offer_id  \
# 1074  france-travail-api  2937063
# 1075  france-travail-api  5084499
# 1076  france-travail-api  5084011
# 1077  france-travail-api  4513094
# 1078  france-travail-api  2641613
#
#                                                     url  \
# 1074  https://candidat.francetravail.fr/offres/reche...
# 1075  https://candidat.francetravail.fr/offres/reche...
# 1076  https://candidat.francetravail.fr/offres/reche...
# 1077  https://candidat.francetravail.fr/offres/reche...
# 1078  https://candidat.francetravail.fr/offres/reche...
#
#                                                   title  \
# 1074  Lead Développeur Data (Spark / Scala) - Grande...
# 1075  Data Engineer PySpark - Data Factory - Service...
# 1076  Data Engineer PySpark - Data Factory - Service...
# 1077            Data Engineer GCP / Airflow / dbt (H/F)
# 1078      Concepteur/Développeur/Testeur DBT-ASAP (H/F)
#
#                       company                       location  \
# ...
